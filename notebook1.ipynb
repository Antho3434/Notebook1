# %%
# %%HTML
# <!DOCTYPE html>
# <html lang="en">
#   <head>
#     <meta charset="utf-8" />
#     <meta name="viewport" content="width=device-width, initial-scale=1" />
#     <link rel="icon" href="https://glitch.com/favicon.ico" />
#
#     <title>Tu vas adorer!!!</title>
#
#     <!-- import the webpage's stylesheet -->
#     <link rel="stylesheet" href="/style.css" />
#
#     <!-- import the webpage's javascript file -->
#     <script src="/script.js" defer></script>
#   </head>
#   <body>
#     <!-- this is the start of content -->
#     <h1>
#       LES JEUX VIDEOS
#     </h1>
#     <p>
#       Bonjour, je m'appelle ANTHONY et ma passion est les jeux vidéos.
#       Je suis passionné de jeux vidéos depuis ma tendre enfance. Mais c'est
#       quoi les jeux vidéo ?
#     </p>
#     <p>
#       <img src="https://cdn.glitch.me/d782652f-2829-417b-b2c0-943169ca5a34/mario.jpg?v=1639559275833"
#     </p>
#       <img src="https://cdn.glitch.me/d782652f-2829-417b-b2c0-943169ca5a34/among%20us.png?v=1640014299989" width=250px
#            </p>
#         <img src="https://cdn.glitch.me/d782652f-2829-417b-b2c0-943169ca5a34/geom%C3%A9trie%20dash.jfif?v=1640014933131" width=250px
#              </p>
#     <p>
#       Un jeu vidéo est un jeu électronique doté d'une interface utilisateur
#       permettant une interaction humaine ludique en générant un retour visuel
#       sur un dispositif vidéo. Le joueur de jeu vidéo dispose de périphériques
#       pour agir sur le jeu et percevoir les conséquences de ses actes sur un
#       environnement virtuel.
#     </p>
#
#            <p>
#            <img src="https://cdn.glitch.me/d782652f-2829-417b-b2c0-943169ca5a34/meme.jfif?v=1640014546656" width=400px
#                 </p>
#            <img src="https://cdn.glitch.me/d782652f-2829-417b-b2c0-943169ca5a34/pac%20man.gif?v=1639664773421" width=355px
#     </p>
#       <p>
#     Voici une petite vidéo sur le thème:
#     </p>
#     <p>
#       <iframe width="900" height="535" src="https://www.youtube.com/embed/8EiGun6Etfg" title="YouTube video player" frameborder="0" allow="accelerometer; autoplay; clipboard-write; encrypted-media; gyroscope; picture-in-picture" allowfullscreen></iframe>
#       </p>
#       <h2>
#       MERCI D'AVOIR REGARDE MON SITE!!!!
#       Je vous conseille d'aller faire un tour sur le site de mon ami,
#         il est très bien. Il y a plein de bonnes choses qui pourraient vous intéresser
#         alors cliquez pour découvrir. --->
#     <a href="https://adaptable-rainbow-blackcurrant.glitch.me"
#         target="_blank">ici</a
#       >
#     </h2>
#     </p>
#     <img src="https://cdn.glitch.me/d782652f-2829-417b-b2c0-943169ca5a34/face_co.png?v=1639558839334" width=100px
#     <h2>
#   ANTHONY
# </h2>
#   </body>
# </html>
# Out:
# <h1>Je m'appelle Anthony</h1>
